# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,.3f}'.format
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston

# %%
boston = load_boston()
df = pd.DataFrame(boston.data, columns=boston.feature_names)
df['target'] = boston.target

# %%
df
# Out:
#      CRIM     ZN  INDUS  CHAS   NOX    RM    AGE   DIS   RAD     TAX  PTRATIO  \
# 0   0.006 18.000  2.310 0.000 0.538 6.575 65.200 4.090 1.000 296.000   15.300
# 1   0.027  0.000  7.070 0.000 0.469 6.421 78.900 4.967 2.000 242.000   17.800
# 2   0.027  0.000  7.070 0.000 0.469 7.185 61.100 4.967 2.000 242.000   17.800
# 3   0.032  0.000  2.180 0.000 0.458 6.998 45.800 6.062 3.000 222.000   18.700
# 4   0.069  0.000  2.180 0.000 0.458 7.147 54.200 6.062 3.000 222.000   18.700
# ..    ...    ...    ...   ...   ...   ...    ...   ...   ...     ...      ...
# 501 0.063  0.000 11.930 0.000 0.573 6.593 69.100 2.479 1.000 273.000   21.000
# 502 0.045  0.000 11.930 0.000 0.573 6.120 76.700 2.288 1.000 273.000   21.000
# 503 0.061  0.000 11.930 0.000 0.573 6.976 91.000 2.167 1.000 273.000   21.000
# 504 0.110  0.000 11.930 0.000 0.573 6.794 89.300 2.389 1.000 273.000   21.000
# 505 0.047  0.000 11.930 0.000 0.573 6.030 80.800 2.505 1.000 273.000   21.000
#
#           B  LSTAT  target
# 0   396.900  4.980  24.000
# 1   396.900  9.140  21.600
# 2   392.830  4.030  34.700
# 3   394.630  2.940  33.400
# 4   396.900  5.330  36.200
# ..      ...    ...     ...
# 501 391.990  9.670  22.400
# 502 396.900  9.080  20.600
# 503 396.900  5.640  23.900
# 504 393.450  6.480  22.000
# 505 396.900  7.880  11.900
#
# [506 rows x 14 columns]

# %%
# 前処理: カテゴリ変数化
df.RAD = df.RAD.astype(np.int8)
df.RAD = df.RAD.map(lambda x: chr(x - 1 + ord('A')) )

# %% [markdown]
# ## 統計量(平均，中央，四分位)

# %%
df.describe()
# Out:
#          CRIM      ZN   INDUS    CHAS     NOX      RM     AGE     DIS     TAX  \
# count 506.000 506.000 506.000 506.000 506.000 506.000 506.000 506.000 506.000
# mean    3.614  11.364  11.137   0.069   0.555   6.285  68.575   3.795 408.237
# std     8.602  23.322   6.860   0.254   0.116   0.703  28.149   2.106 168.537
# min     0.006   0.000   0.460   0.000   0.385   3.561   2.900   1.130 187.000
# 25%     0.082   0.000   5.190   0.000   0.449   5.886  45.025   2.100 279.000
# 50%     0.257   0.000   9.690   0.000   0.538   6.208  77.500   3.207 330.000
# 75%     3.677  12.500  18.100   0.000   0.624   6.623  94.075   5.188 666.000
# max    88.976 100.000  27.740   1.000   0.871   8.780 100.000  12.127 711.000
#
#        PTRATIO       B   LSTAT  target
# count  506.000 506.000 506.000 506.000
# mean    18.456 356.674  12.653  22.533
# std      2.165  91.295   7.141   9.197
# min     12.600   0.320   1.730   5.000
# 25%     17.400 375.377   6.950  17.025
# 50%     19.050 391.440  11.360  21.200
# 75%     20.200 396.225  16.955  25.000
# max     22.000 396.900  37.970  50.000

# %% [markdown]
# ## 最頻値

# %%
df.mode().iloc[0]
# Out:
# CRIM        0.015
# ZN          0.000
# INDUS      18.100
# CHAS        0.000
# NOX         0.538
# RM          5.713
# AGE       100.000
# DIS         3.495
# RAD             X
# TAX       666.000
# PTRATIO    20.200
# B         396.900
# LSTAT       6.360
# target     50.000
# Name: 0, dtype: object

# %% [markdown]
# ## Box Chart

# %%
plt.boxplot(df.AGE)
plt.show()
